# %%
# ✅ Célula de setup — execute esta primeiro!
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Deixando os resultados sempre iguais
np.random.seed(42)

# Criando uma base simples de alunos
n = 60
alunos = pd.DataFrame({
    'turma': np.random.choice(['A', 'B'], size=n),
    'horas_estudo': np.random.normal(5, 1.5, size=n).clip(1, 9),
    'faltas': np.random.poisson(3, size=n),
})

# Criando uma nota com relação simples com horas de estudo e faltas
alunos['nota'] = (
    5 + alunos['horas_estudo'] * 0.7 - alunos['faltas'] * 0.25 + np.random.normal(0, 0.8, size=n)
).clip(0, 10)

alunos.head()

# %% [markdown]
# ### 🏋️ Exercício — Seaborn e Análise Estatística
#
# **Desafio:** usando a base `alunos`, crie uma análise visual simples com Seaborn contendo:
#
# - Um **histograma com KDE** da coluna `nota`, separado por `turma` usando `hue`;
# - Um **boxplot** de `nota` por `turma`;
# - Um **stripplot** por cima do boxplot para visualizar os pontos individuais;
# - Um **scatter plot** mostrando a relação entre `horas_estudo` e `nota`, também separado por `turma` com `hue`;
# - Um **heatmap** com a matriz de correlação das colunas numéricas.
#
# O objetivo é praticar os conceitos principais do Módulo 3: `hue`, distribuições, outliers, relacionamento entre variáveis e correlação.
#
# Mantenha os gráficos simples e com títulos claros.

# %%
# 👇 Escreva sua solução aqui

# 1) Histograma com KDE


# 2) Boxplot + Stripplot


# 3) Scatter plot com hue


# 4) Heatmap de correlação
